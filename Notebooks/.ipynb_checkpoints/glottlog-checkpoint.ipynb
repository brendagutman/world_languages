# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
lang = pd.read_csv("../Data/languages_data.csv")
lang
# Out:
#           pk        id             name  latitude  longitude  speakers_count  \
# 0          1  kond1302   Konda-Yahadian       NaN        NaN             NaN
# 1          2  cani1243        Canichana  -14.3058 -64.944455             NaN
# 2          3  mong1349  Mongolic-Khitan       NaN        NaN             NaN
# 3          4  cadd1255          Caddoan       NaN        NaN             NaN
# 4          5  yuki1242       Yuki-Wappo       NaN        NaN             NaN
# ...      ...       ...              ...       ...        ...             ...
# 25434  25435  wall1259           Wallon       NaN        NaN             NaN
# 25435  25436  norm1245          Normand       NaN        NaN             NaN
# 25436  25437  sant1407      Santongeais       NaN        NaN             NaN
# 25437  25438  poit1240         Poitevin       NaN        NaN             NaN
# 25438  25439  lorr1242         Lorraine       NaN        NaN             NaN
#
# ...

# %%
lang_clean = lang[['pk','id','name','level','macroareas','status']]
lang_clean['status'] = lang_clean['status'].replace(np.nan,'Unknown')
lang_clean
# Out:
# <ipython-input-15-212395aa7660>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lang_clean['status'] = lang_clean['status'].replace(np.nan,'Unknown')
#           pk        id             name     level     macroareas   status
# 0          1  kond1302   Konda-Yahadian    family      Papunesia  Unknown
# 1          2  cani1243        Canichana  language  South America  extinct
# 2          3  mong1349  Mongolic-Khitan    family        Eurasia  Unknown
# 3          4  cadd1255          Caddoan    family  North America  Unknown
# 4          5  yuki1242       Yuki-Wappo    family  North America  Unknown
# ...      ...       ...              ...       ...            ...      ...
# ...
